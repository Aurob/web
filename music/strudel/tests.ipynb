# %%
sound_names = "insect wind jazz metal east crow casio space numbers".split(' ')

# %%
print('\n'.join([f'sound("{s}")' for s in sound_names]))
# Out:
# sound("insect")
# sound("wind")
# sound("jazz")
# sound("metal")
# sound("east")
# sound("crow")
# sound("casio")
# sound("space")
# sound("numbers")
